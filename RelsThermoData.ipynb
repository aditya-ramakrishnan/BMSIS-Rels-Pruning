# %%
import numpy as np
import pandas as pd
from equilibrator_api import ComponentContribution, Q_
CC = ComponentContribution()
from equilibrator_assets.generate_compound import create_compound, get_or_create_compound

# %%
from ast import literal_eval

# %%
def CacheGen(filepath):
    df = pd.read_csv(filepath, sep='\t') 
    
    Compounds = []
    Reagents = []
    Products = []
    
    for i in range(len(df)):
        if df['TYPE'][i] == -1:
            reagent = df['COMPOUND'][i]
            Reagents.append(reagent)
            if reagent not in Compounds:
                Compounds.append(reagent)
        else:
            product = df['COMPOUND'][i]
            Products.append(product)
            if product not in Compounds:
                Compounds.append(product)
    
    compound_cache = get_or_create_compound(CC.ccache, Compounds, mol_format="smiles", error_log='./ErrorLog.tsv')
    
    return(compound_cache, Compounds)

# %%
def ThermoGen(filepath, compound_cache, Compounds, name):
    df = pd.read_csv(filepath, sep='\t')
    IDs = []
    Rules = []
    Reagents = []
    Products = []
    for i in range(len(df)):
        if df['ID'][i] not in IDs:
            IDs.append(df['ID'][i])
            Rules.append(df['RULE'][i])
        
    mus = []
    sigma_vecs = []
    for c in compound_cache:
        mu = (CC.predictor.preprocess.get_compound_prediction(c))[0]
        sigma_vec = (CC.predictor.preprocess.get_compound_prediction(c))[1]
        mus.append(mu)
        sigma_vecs.append(sigma_vec)
    
    error_log = pd.read_csv('./ErrorLog.tsv', sep='\t')
    final_compounds = []
    for i in range(len(Compounds)):
        if error_log['status'][i] == 'valid':
            final_compounds.append(Compounds[i])

    print(len(mus))
    print(len(final_compounds))
    
    EnergyChanges = []
    i = 0
    while i < len(df):
        dummy_mus = []
        dummy_sigma_vecs = []
        dummy_compounds = []
        dummy_coefficients = []
        rxn_reactant = ""
        rxn_product = ""
        if df['TYPE'][i] == -1:
            reagent = df['COMPOUND'][i]
            dummy_compounds.append(reagent)
            dummy_coefficients.append(-1)
            rxn_reactant = reagent
        else:
            product = df['COMPOUND'][i]
            dummy_compounds.append(product)
            dummy_coefficients.append(1)
            rxn_product = product
        if i <= (len(df)-2):
            while (df['ID'][i] == df['ID'][i+1]):
                i+=1
                if df['TYPE'][i] == -1:
                    reagent = df['COMPOUND'][i]
                    dummy_compounds.append(reagent)
                    dummy_coefficients.append(-1)
                    if rxn_reactant != "":
                        rxn_reactant = rxn_reactant + ", " + reagent
                    else:
                        rxn_reactant = reagent
                else:
                    product = df['COMPOUND'][i]
                    dummy_compounds.append(product)
                    dummy_coefficients.append(1)
                    if rxn_product != "":
                        rxn_product = rxn_product + ", " + product
                    else:
                        rxn_product = product
                if i == (len(df)-1):
                    break
        i+=1
        rxn_reactant = [rxn_reactant]; rxn_product = [rxn_product]
        Reagents.append(rxn_reactant); Products.append(rxn_product)
        valid_reaction = True
        for m in range(len(dummy_compounds)):
            if dummy_compounds[m] not in final_compounds:
                valid_reaction = False
                break
            else: 
                dummy_mus.append(mus[final_compounds.index(dummy_compounds[m])])
                dummy_sigma_vecs.append(sigma_vecs[final_compounds.index(dummy_compounds[m])])
        if valid_reaction == True:
            S = np.zeros(len(dummy_compounds))
            for n in range(len(dummy_coefficients)):
                S[n] = dummy_coefficients[n]
            dummy_mus = Q_(dummy_mus, "kJ/mol")
            dummy_sigma_vecs = Q_(dummy_sigma_vecs, "kJ/mol")
            standard_dgs = S.T @ dummy_mus
            U = S.T @ dummy_sigma_vecs
            EnergyChanges.append(standard_dgs._magnitude.round(2))
        else:
            EnergyChanges.append('NaN')
    
    outputdata = {'ID':IDs, 'REAGENTS':Reagents, 'PRODUCTS':Products, 'RULE':Rules, 'ENERGY CHANGE':EnergyChanges}
    outputdf = pd.DataFrame(outputdata)
    outputdf.to_csv(f'{name}_WithThermo.tsv', header=None, index=None, sep='\t', mode='a')
    return(outputdf)

# %%
# %%time
a, b = CacheGen('~/Desktop/Aditya/tsv_rels/rels_1.tsv')
a = ThermoGen('~/Desktop/Aditya/tsv_rels/rels_1.tsv', a, b, 'Rels_1')
a
# Out:
# 21
# 21
# CPU times: user 13.4 s, sys: 8.14 s, total: 21.5 s
# Wall time: 35 s
#       ID                                           REAGENTS  \
# 0    5_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 1    5_1                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 2    7_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 3    9_0                       [N, C(C(C(C(C(CO)O)O)O)O)=O]
# 4   12_0  [O, C(C(C(C(C(CO)O)O)O)O)=O, C(C(C(C(C(CO)O)O)...
# 5   12_1  [O, C(C(C(C(C(CO)O)O)O)O)=O, C(C(C(C(C(CO)O)O)...
# 6   14_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 7   16_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 8   18_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 9   20_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 10  22_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 11  24_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 12  26_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 13  28_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 14  30_0                       [N, C(C(C(C(C(CO)O)O)O)O)=O]
# 15  32_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 16  34_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 17  36_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
#
#                                              PRODUCTS  \
# 0                          [C(CO)=O, C(C(C(CO)O)O)=O]
# 1                          [C(CO)=O, C(C(C(CO)O)O)=O]
# 2                           [C(CO)(C(C(C(CO)O)O)O)=O]
# 3                        [O, C(CN)(C(C(C(CO)O)O)O)=O]
# 4   [C(C(C(C(C(CO)O)O)O)O)(O)=O, C(C(C(C(C(CO)O)O)...
# 5   [C(C(C(C(C(CO)O)O)O)O)(O)=O, C(C(C(C(C(CO)O)O)...
# 6                          [O, C(C(CC(C(CO)O)O)=O)=O]
# 7                          [O, C(CC(C(C(CO)O)O)=O)=O]
# 8                          [O, C(C(C(CC(CO)O)=O)O)=O]
# 9                          [O, C(CC(C=O)O)(C(CO)O)=O]
# 10                         [O, C(C(C(C=O)O)O)(CCO)=O]
# 11                         [O, C(C(C(CC(CO)=O)O)O)=O]
# 12                       [O, C(C(C(C(C(C)=O)O)O)O)=O]
# 13                         [O, C(CC(C(C(C=O)O)O)O)=O]
# 14                       [O, C(C(C(C(C(CO)O)O)N)O)=O]
# 15                         [C(C(C1C(C(C(O)O1)O)O)O)O]
# 16                         [C(C1C(C(C(C(O)O1)O)O)O)O]
# 17                         [C1C(C(C(C(C(O)O1)O)O)O)O]
#
#                                          RULE  ENERGY CHANGE
# 0                                 Retro Aldol          13.37
# 1                         Knoevenagel H (inv)          13.37
# 2                   Keto-enol migration twice          -2.00
# 3                 Amadori/Heyns Rearrangement         -20.34
# 4           Cannizarro 2, glucose (oxidation)         -17.27
# 5           Cannizarro 2, glucose (reduction)         -17.27
# 6                  Elimination + enol to keto         -41.01
# 7                  Elimination + enol to keto         -53.84
# 8                  Elimination + enol to keto         -97.97
# 9                  Elimination + enol to keto         -41.01
# 10                 Elimination + enol to keto         -41.01
# 11                 Elimination + enol to keto         -41.01
# 12                 Elimination + enol to keto         -45.40
# 13                 Elimination + enol to keto         -39.01
# 14                           Mannich Addition         -11.61
# 15  Hemiacetal Formation for 5 membered rings          -1.45
# 16  Hemiacetal Formation for 6 membered rings          -4.15
# 17  Hemiacetal Formation for 7 membered rings          -7.01

# %%
# %%time
a, b = CacheGen('~/Desktop/Aditya/tsv_rels/rels_2.tsv')
a = ThermoGen('~/Desktop/Aditya/tsv_rels/rels_2.tsv', a, b, 'Rels_2')
a
# Out:
# 180
# 180
# CPU times: user 1min 42s, sys: 1min 2s, total: 2min 45s
# Wall time: 3min 1s
#         ID                                           REAGENTS  \
# 0      5_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 1      5_1                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 2      7_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 3      9_0                       [N, C(C(C(C(C(CO)O)O)O)O)=O]
# 4     12_0  [O, C(C(C(C(C(CO)O)O)O)O)=O, C(C(C(C(C(CO)O)O)...
# ..     ...                                                ...
# 280  432_0                         [C(C1C(C(C(C(O)O1)O)O)O)O]
# 281  433_0                         [C1C(C(C(C(C(O)O1)O)O)O)O]
# 282  435_0                       [C(C(C(C(C(CO)O)O)O)O)(O)=O]
# 283  437_0                       [C(C(C(C(C(CO)O)O)O)O)(O)=O]
# 284  439_0                       [C(C(C(C(C(CO)O)O)O)O)(O)=O]
#
#                                               PRODUCTS  \
# 0                           [C(CO)=O, C(C(C(CO)O)O)=O]
# 1                           [C(CO)=O, C(C(C(CO)O)O)=O]
# 2                            [C(CO)(C(C(C(CO)O)O)O)=O]
# 3                         [O, C(CN)(C(C(C(CO)O)O)O)=O]
# 4    [C(C(C(C(C(CO)O)O)O)O)(O)=O, C(C(C(C(C(CO)O)O)...
# ..                                                 ...
# 280                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 281                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 282                     [O, C1(C(C(C(C(CO)O)O1)O)O)=O]
# 283                     [O, C1(C(C(C(C(CO)O1)O)O)O)=O]
# 284                     [O, C1(C(C(C(C(CO1)O)O)O)O)=O]
#
#                                                   RULE  ENERGY CHANGE
# 0                                          Retro Aldol          13.37
# 1                                  Knoevenagel H (inv)          13.37
# 2                            Keto-enol migration twice          -2.00
# 3                          Amadori/Heyns Rearrangement         -20.34
# 4                    Cannizarro 2, glucose (oxidation)         -17.27
# ..                                                 ...            ...
# 280  Hemiacetal Formation for 6 membered rings, inv...           4.15
# 281  Hemiacetal Formation for 7 membered rings, inv...           7.01
# 282                       Ring Closure 5 membered O, O         -20.13
# 283                       Ring Closure 6 membered O, O         -22.83
# 284                       Ring Closure 7 membered O, O         -25.68
#
# [285 rows x 5 columns]

# %%
# %%time
a, b = CacheGen('~/Desktop/Aditya/tsv_rels/rels_3.tsv')
a = ThermoGen('~/Desktop/Aditya/tsv_rels/rels_3.tsv', a, b, 'Rels_3')
a
# Out:
# WARNING:equilibrator_assets.generate_compound:One or more compounds were unable to be decomposed. Rerun specifying error_log or log_df to view details.
# 1866
# 1866
# CPU times: user 16min 1s, sys: 8min 51s, total: 24min 53s
# Wall time: 3h 26min 32s
#           ID                                           REAGENTS  \
# 0        5_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 1        5_1                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 2        7_0                          [C(C(C(C(C(CO)O)O)O)O)=O]
# 3        9_0                       [N, C(C(C(C(C(CO)O)O)O)O)=O]
# 4       12_0  [O, C(C(C(C(C(CO)O)O)O)O)=O, C(C(C(C(C(CO)O)O)...
# ...      ...                                                ...
# 3948  4987_0                            [C(C(CC(C(C=O)O)O)N)=O]
# 3949  4989_0                            [C(C(C(CC(CO)=O)N)O)=O]
# 3950  4991_0                            [C(C(CC(C(CO)O)N)=O)=O]
# 3951  4993_0                            [C(C(C(CC(CO)N)=O)O)=O]
# 3952  4995_0                            [C(CC(C(C(C=O)O)O)N)=O]
#
#                                                PRODUCTS  \
# 0                            [C(CO)=O, C(C(C(CO)O)O)=O]
# 1                            [C(CO)=O, C(C(C(CO)O)O)=O]
# 2                             [C(CO)(C(C(C(CO)O)O)O)=O]
# 3                          [O, C(CN)(C(C(C(CO)O)O)O)=O]
# 4     [C(C(C(C(C(CO)O)O)O)O)(O)=O, C(C(C(C(C(CO)O)O)...
# ...                                                 ...
# 3948                           [C(C(CO)O)=O, C=C(C=O)N]
# 3949                           [C(CO)=O, C(N)=CC(CO)=O]
# 3950                           [C(CO)O, C(N)=CC(C=O)=O]
# 3951                           [CO, C(C(C(C=CN)=O)O)=O]
# 3952                           [C(C(CO)O)=O, C(N)=CC=O]
#
#                                    RULE ENERGY CHANGE
# 0                           Retro Aldol         13.37
# 1                   Knoevenagel H (inv)         13.37
# 2             Keto-enol migration twice          -2.0
# 3           Amadori/Heyns Rearrangement        -20.34
# 4     Cannizarro 2, glucose (oxidation)        -17.27
# ...                                 ...           ...
# 3948    Michael Addition 0,2, (reverse)         71.38
# 3949    Michael Addition 0,2, (reverse)          72.8
# 3950    Michael Addition 0,2, (reverse)         69.77
# 3951    Michael Addition 0,2, (reverse)         64.91
# 3952    Michael Addition 0,2, (reverse)         69.77
#
# [3953 rows x 5 columns]

# %%
# %%time
a, b = CacheGen('~/Desktop/Aditya/tsv_rels/rels_4.tsv')
a = ThermoGen('~/Desktop/Aditya/tsv_rels/rels_4.tsv', a, b, 'Rels_4')
a
